# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

# data: list of word indices
# count: list of (word, count) tuples
# dictionary: word -> word index
# reverse_dictionary: word index -> word

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  # Initial sequence of `span` number of words, used to 
  # generate the skip-grams in the first window.
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # For each word, we generate num_skips worth of skip-grams.
  # Since we want at most batch_size number of skips, we can only 
  # iterate `batch_size // num_skips` number of times.
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    # For each target word, generate num_skips worth of skip-grams.
    for j in range(num_skips):
      # Brute force search of an unprocessed word index
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      # Generate word -> skip pairing
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    # Update the buffer to contain the next word in the sentence, 
    # removing the first word from the buffer at the same time
    buffer.append(data[data_index])
    # Update pointer to next word in sentence
    data_index = (data_index + 1) % len(data)
  return batch, labels

def skipgram_generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window

    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    batch = []
    labels = []
    for _ in range(batch_size // num_skips):
        input_word = buffer[skip_window]
        # Maybe this can be shuffled
        output_words = list(buffer)[0:skip_window] + list(buffer)[2:]
        for word in output_words[0:num_skips]:
            batch.append(input_word)
            labels.append(word)
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    batch = np.array(batch).astype(np.int32)
    labels = np.array(labels).astype(np.int32).reshape(-1, 1)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2), (2, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
    data_index = 0
    batch, labels = skipgram_generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'term', 'as', 'originated', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'as', 'a', 'originated', 'as', 'a', 'term']
#
# with num_skips = 2 and skip_window = 2:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of']
#     labels: ['originated', 'a', 'originated', 'of', 'abuse', 'a', 'first', 'abuse']
#
# with num_skips = 2 and skip_window = 2:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of']
#     labels: ['anarchism', 'originated', 'originated', 'as', 'as', 'a', 'a', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = skipgram_generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.191150
# Nearest to these: mehmet, cheddar, groom, queen, plunder, aristocratic, townshend, handsome,
# Nearest to see: wed, vh, salicylic, undernet, scholarships, phenotype, demonstrate, toughest,
# Nearest to with: mist, seconds, comma, holds, kayaks, chapultepec, andersonville, soprano,
# Nearest to was: bulgars, tire, imperialist, partido, estuary, owyn, fleischer, leslie,
# Nearest to one: fenian, rewritten, objector, csm, tolerable, welcomed, spence, rationalize,
# Nearest to that: farrell, gametes, monsoons, saints, adonis, visions, twentieth, desiring,
# Nearest to had: marx, lightbulb, ls, unconstitutional, reinstate, liberally, beds, pesos,
# Nearest to people: leaned, azeotrope, aarhus, offending, carrero, devas, garrisoned, architecturally,
# Nearest to have: instrumentalists, doomed, abhorrent, trieste, lycia, paleozoic, earthdawn, manaus,
# Nearest to over: annoying, babel, encodings, reporters, kwan, ladders, models, priesthood,
# Nearest to some: driver, investors, kai, tco, eccentric, lakeshore, cytosol, globalisation,
# Nearest to two: volhynia, ece, mdma, fredrik, circ, kinematic, respectfully, syndicate,
# Nearest to not: laika, subclass, freeport, shore, purged, snakes, shreck, supports,
# Nearest to called: warranted, undetectable, suu, purely, mai, circumnavigation, misspelling, reformers,
# Nearest to are: specificity, zil, deeply, goalkeeper, radiocommunication, mordred, attested, nchez,
# Nearest to when: shipper, shaving, shalmaneser, airliner, shiva, rake, gangs, charlottetown,
# Average loss at step 2000: 4.356734
# Average loss at step 4000: 3.865673
# Average loss at step 6000: 3.788932
# Average loss at step 8000: 3.690284
# Average loss at step 10000: 3.615471
# Nearest to these: many, examples, some, flight, revisionist, factories, sobriquet, taunton,
# Nearest to see: undernet, linus, trypanosomiasis, wed, crux, wic, pakistani, scholarships,
# Nearest to with: in, between, on, by, through, exogenous, uss, powered,
# Nearest to was: is, has, were, had, been, by, be, micromachining,
# Nearest to one: two, seven, six, three, arkham, bourgeoisie, guarani, factorial,
# Nearest to that: which, it, what, predicting, nouakchott, souls, lost, also,
# Nearest to had: has, have, was, marx, lightbulb, unconstitutional, brighton, landowner,
# Nearest to people: architecturally, reiterated, hitchens, sternberg, garrisoned, destruct, offending, motel,
# Nearest to have: had, be, has, abhorrent, dcsd, include, warrior, are,
# Nearest to over: annoying, encodings, reporters, crime, babel, models, priesthood, shirley,
# Nearest to some: many, lakeshore, these, ishikawa, antietam, hopkins, driver, federalism,
# Nearest to two: five, four, three, seven, six, eight, zero, nine,
# Nearest to not: also, it, shreck, we, supports, biochemists, laika, joules,
# Nearest to called: warranted, mai, nouveau, undetectable, backbone, mundane, structured, festivities,
# Nearest to are: were, is, trend, courteous, radiocommunication, include, was, be,
# Nearest to when: rake, if, bile, intermittent, keel, geomagnetic, charlottetown, rivalries,
# Average loss at step 12000: 3.606195
# Average loss at step 14000: 3.566323
# Average loss at step 16000: 3.407721
# Average loss at step 18000: 3.457728
# Average loss at step 20000: 3.544046
# Nearest to these: many, some, all, they, examples, which, various, periodicity,
# Nearest to see: linus, trypanosomiasis, undernet, riflemen, scholarships, wic, muhammed, dessau,
# Nearest to with: between, in, at, through, gamal, annex, bret, vita,
# Nearest to was: is, were, has, had, be, been, are, does,
# Nearest to one: two, four, three, seven, six, five, eight, nine,
# Nearest to that: which, but, however, ludicrous, what, reggie, cheques, also,
# Nearest to had: has, have, were, was, landowner, having, sacd, lightbulb,
# Nearest to people: stays, hitchens, holographic, circling, sternberg, transcendentalism, guillaume, luba,
# Nearest to have: had, has, be, were, assimilation, are, abhorrent, dcsd,
# Nearest to over: annoying, reporters, shirley, encodings, bulky, vagantes, between, crime,
# Nearest to some: many, these, all, several, most, their, any, other,
# Nearest to two: three, four, five, six, one, seven, eight, nine,
# Nearest to not: also, it, to, they, generally, now, shreck, joules,
# Nearest to called: warranted, animals, structured, nouveau, undetectable, floats, backbone, mai,
# Nearest to are: were, is, was, have, courteous, patriot, weak, trend,
# Nearest to when: if, bile, rake, however, doren, intermittent, geomagnetic, debugging,
# Average loss at step 22000: 3.505075
# Average loss at step 24000: 3.492829
# Average loss at step 26000: 3.482922
# Average loss at step 28000: 3.477679
# Average loss at step 30000: 3.500768
# Nearest to these: some, many, several, all, they, such, various, which,
# Nearest to see: trypanosomiasis, linus, borda, undernet, scholarships, holberg, ib, utilized,
# Nearest to with: between, for, in, bret, gamal, against, smpte, serving,
# Nearest to was: is, were, had, has, been, became, by, be,
# Nearest to one: seven, two, four, eight, three, six, five, nine,
# Nearest to that: which, however, what, but, this, meninges, therefore, lost,
# Nearest to had: have, has, was, having, were, landowner, herder, trios,
# Nearest to people: holographic, circling, those, bipm, reiterated, stays, trams, men,
# Nearest to have: had, has, were, are, be, include, assimilation, having,
# Nearest to over: annoying, between, vagantes, unnamed, reporters, bulky, shirley, crime,
# Nearest to some: many, these, several, all, any, their, most, royston,
# Nearest to two: four, three, seven, five, eight, six, one, nine,
# Nearest to not: it, generally, now, they, bartleby, altay, forever, keyes,
# Nearest to called: warranted, structured, competitiveness, used, backbone, jacobian, tact, nouveau,
# Nearest to are: were, have, is, include, these, courteous, penzance, other,
# Nearest to when: if, after, before, but, where, however, although, bile,
# Average loss at step 32000: 3.498432
# Average loss at step 34000: 3.491108
# Average loss at step 36000: 3.456978
# Average loss at step 38000: 3.305330
# Average loss at step 40000: 3.436339
# Nearest to these: many, some, several, various, both, they, those, such,
# Nearest to see: ib, trypanosomiasis, linus, utilized, angered, known, undernet, borda,
# Nearest to with: between, smpte, bret, by, make, on, mysql, when,
# Nearest to was: is, has, had, became, were, been, be, anonymous,
# Nearest to one: four, seven, two, six, three, eight, five, nine,
# Nearest to that: which, what, this, however, usually, ludicrous, it, recovered,
# Nearest to had: has, have, was, having, were, since, meister, herder,
# Nearest to people: rube, individuals, trams, holographic, members, things, reiterated, satirists,
# Nearest to have: had, has, were, be, are, include, having, prefer,
# Nearest to over: between, constantius, disagreement, annoying, warehouse, reporters, cosgrave, transistor,
# Nearest to some: many, these, several, any, both, all, lunch, vacant,
# Nearest to two: four, three, six, five, seven, eight, one, nine,
# Nearest to not: altay, often, they, now, also, vacancies, therefore, it,
# Nearest to called: considered, named, used, margot, tact, warranted, yahoo, sayer,
# Nearest to are: were, is, have, be, although, include, parton, eisler,
# Nearest to when: if, before, after, where, although, but, while, wissowa,
# Average loss at step 42000: 3.436398
# Average loss at step 44000: 3.452908
# Average loss at step 46000: 3.451804
# Average loss at step 48000: 3.355744
# Average loss at step 50000: 3.385102
# Nearest to these: many, some, several, various, both, such, those, all,
# Nearest to see: angered, references, pryor, undernet, leviticus, amritsar, hellenism, trypanosomiasis,
# Nearest to with: between, smpte, bret, ensuing, accents, when, gastroenterology, mattia,
# Nearest to was: is, became, has, were, had, be, been, by,
# Nearest to one: two, six, eight, four, seven, five, three, nine,
# Nearest to that: which, however, what, this, but, meninges, asoka, predicting,
# Nearest to had: has, have, was, having, were, been, since, chronicled,
# Nearest to people: men, members, rube, holographic, others, individuals, dari, critics,
# Nearest to have: had, has, were, are, be, include, having, stricture,
# Nearest to over: between, on, annoying, constantius, disagreement, descendent, bath, plummer,
# Nearest to some: many, these, several, both, any, the, various, all,
# Nearest to two: four, three, six, eight, seven, five, one, zero,
# Nearest to not: now, they, generally, still, vacancies, often, therefore, altay,
# Nearest to called: named, used, rix, sayer, described, borax, margot, der,
# Nearest to are: were, is, have, include, be, those, rebellions, although,
# Nearest to when: if, after, before, but, while, although, where, though,
# Average loss at step 52000: 3.436734
# Average loss at step 54000: 3.423413
# Average loss at step 56000: 3.439014
# Average loss at step 58000: 3.394060
# Average loss at step 60000: 3.392227
# Nearest to these: many, some, several, both, such, those, all, various,
# Nearest to see: references, angered, amritsar, but, list, repeat, motivational, interpretive,
# Nearest to with: between, bret, lexicon, disused, by, gamal, in, vita,
# Nearest to was: is, had, became, were, has, when, be, been,
# Nearest to one: two, six, seven, four, eight, three, five, nine,
# Nearest to that: which, what, however, this, meninges, it, why, there,
# Nearest to had: have, has, was, having, were, meister, been, aedui,
# Nearest to people: members, men, individuals, others, critics, lenition, those, dari,
# Nearest to have: had, has, are, were, include, be, having, prefer,
# Nearest to over: between, constantius, descendent, disagreement, through, connoisseurs, about, into,
# Nearest to some: many, several, these, any, all, both, the, most,
# Nearest to two: three, five, four, six, one, eight, seven, zero,
# Nearest to not: now, still, vacancies, generally, largely, almost, you, therefore,
# Nearest to called: used, considered, named, borax, known, rix, described, margot,
# Nearest to are: were, have, is, include, these, be, including, those,
# Nearest to when: if, although, before, after, during, though, while, where,
# Average loss at step 62000: 3.233284
# Average loss at step 64000: 3.255056
# Average loss at step 66000: 3.406246
# Average loss at step 68000: 3.395795
# Average loss at step 70000: 3.360122
# Nearest to these: many, some, such, several, their, those, various, all,
# Nearest to see: references, amritsar, but, list, related, refers, dimensionless, gunners,
# Nearest to with: between, bret, disused, kurz, while, wallpaper, smpte, lexicon,
# Nearest to was: is, had, has, been, were, became, be, babi,
# Nearest to one: two, six, four, eight, five, seven, nine, three,
# Nearest to that: which, however, what, this, usually, but, typically, why,
# Nearest to had: have, has, was, having, were, been, propellant, chronicled,
# Nearest to people: men, members, students, individuals, critics, dari, damin, others,
# Nearest to have: had, has, are, were, be, include, having, prefer,
# Nearest to over: through, around, about, unnamed, within, between, instill, favorite,
# Nearest to some: many, several, these, most, any, various, other, all,
# Nearest to two: three, four, six, seven, five, one, eight, isbn,
# Nearest to not: now, still, never, largely, generally, usually, only, almost,
# Nearest to called: used, considered, named, known, described, tact, rix, referred,
# Nearest to are: were, is, have, include, although, be, including, eisler,
# Nearest to when: if, while, however, before, where, although, though, after,
# Average loss at step 72000: 3.374412
# Average loss at step 74000: 3.347584
# Average loss at step 76000: 3.316634
# Average loss at step 78000: 3.345210
# Average loss at step 80000: 3.380548
# Nearest to these: many, several, those, some, various, both, such, all,
# Nearest to see: references, related, but, angered, shaivism, madman, amritsar, oise,
# Nearest to with: between, bret, when, gamal, kurz, in, wallpaper, mattia,
# Nearest to was: is, became, were, had, has, been, being, be,
# Nearest to one: seven, two, six, eight, three, four, five, nine,
# Nearest to that: which, however, what, why, where, ludicrous, predicting, this,
# Nearest to had: have, has, having, were, was, herder, meister, chronicled,
# Nearest to people: men, children, members, dari, students, individuals, critics, damin,
# Nearest to have: had, has, include, are, were, be, having, prefer,
# Nearest to over: between, around, within, through, about, lowball, thessaly, instill,
# Nearest to some: many, several, these, most, various, numerous, any, certain,
# Nearest to two: three, four, six, five, seven, one, eight, isbn,
# Nearest to not: still, now, never, usually, often, generally, largely, rarely,
# Nearest to called: named, considered, used, known, described, borax, referred, tact,
# Nearest to are: were, have, although, include, is, eisler, those, including,
# Nearest to when: if, after, before, though, during, while, although, where,
# Average loss at step 82000: 3.405098
# Average loss at step 84000: 3.407925
# Average loss at step 86000: 3.389241
# Average loss at step 88000: 3.350580
# Average loss at step 90000: 3.364930
# Nearest to these: several, many, some, are, those, various, such, both,
# Nearest to see: references, list, interpretive, dimensionless, finnegan, refer, links, bryozoa,
# Nearest to with: between, in, by, smpte, bret, disused, reclusive, leaving,
# Nearest to was: is, became, had, were, has, been, be, being,
# Nearest to one: seven, two, four, eight, three, six, five, nine,
# Nearest to that: which, however, what, why, predicting, recovered, tolerances, but,
# Nearest to had: has, have, were, was, having, since, did, majorca,
# Nearest to people: men, children, students, jews, women, members, individuals, someone,
# Nearest to have: had, has, were, are, having, stricture, be, include,
# Nearest to over: within, around, between, through, off, lowball, instill, thessaly,
# Nearest to some: many, several, these, most, any, both, all, this,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to not: still, now, therefore, we, never, they, almost, foliage,
# Nearest to called: named, known, used, considered, referred, described, rubinstein, margot,
# Nearest to are: were, these, have, is, include, although, including, contain,
# Nearest to when: if, before, while, although, after, where, though, during,
# Average loss at step 92000: 3.399143
# Average loss at step 94000: 3.247328
# Average loss at step 96000: 3.363359
# Average loss at step 98000: 3.241850
# Average loss at step 100000: 3.359168
# Nearest to these: several, many, some, those, various, all, their, both,
# Nearest to see: references, links, according, ostensibly, list, can, refer, undernet,
# Nearest to with: between, including, in, bret, reclusive, mattia, wallpaper, of,
# Nearest to was: is, became, had, were, has, been, becomes, porta,
# Nearest to one: two, four, five, three, seven, eight, six, nine,
# Nearest to that: which, however, what, who, actually, why, tolerances, this,
# Nearest to had: has, have, was, were, having, is, since, would,
# Nearest to people: men, children, jews, students, women, someone, individuals, americans,
# Nearest to have: had, has, include, were, are, having, prefer, stricture,
# Nearest to over: between, descendent, within, around, through, about, instill, interdisciplinary,
# Nearest to some: many, several, these, any, certain, numerous, all, this,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to not: never, still, now, they, truly, almost, therefore, largely,
# Nearest to called: named, considered, known, referred, used, described, bebe, borax,
# Nearest to are: were, have, is, although, these, include, be, while,
# Nearest to when: if, although, before, while, after, where, though, because,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
# %matplotlib inline 

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
